# %% [markdown]
# <a href="https://colab.research.google.com/github/denistoo749/Iris-Computer-Vision/blob/main/iris_species.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Iris Species
# - Classify iris plants into three species in this classic dataset
#
# **Data**
# - It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# - The columns in this dataset are:
#
#     - Id
#     - SepalLengthCm
#     - SepalWidthCm
#     - PetalLengthCm
#     - PetalWidthCm
#     - Species
#
# >https://www.kaggle.com/datasets/uciml/iris/data

# %%
# Unzip files
#!unzip '/content/drive/MyDrive/Iris Species/archive.zip' -d '/content/drive/MyDrive/Iris Species/data/'

# %%
import pandas as pd
df_csv = pd.read_csv('/content/drive/MyDrive/Iris Species/data/Iris.csv')
df_csv.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
len(df_csv)
# Out:
# 150

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
import sqlite3

# Path to your database
database_path = '/content/drive/MyDrive/Iris Species/data/database.sqlite'

# Connect to the database
conn = sqlite3.connect(database_path)
cursor = conn.cursor()

# Example query
cursor.execute("SELECT * FROM Iris")
rows = cursor.fetchall()

# Print the rows
for row in rows:
    print(row)

# Close the connection
# conn.close()
# Out:
# (1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa')
# (2, 4.9, 3, 1.4, 0.2, 'Iris-setosa')
# (3, 4.7, 3.2, 1.3, 0.2, 'Iris-setosa')
# (4, 4.6, 3.1, 1.5, 0.2, 'Iris-setosa')
# (5, 5, 3.6, 1.4, 0.2, 'Iris-setosa')
# (6, 5.4, 3.9, 1.7, 0.4, 'Iris-setosa')
# (7, 4.6, 3.4, 1.4, 0.3, 'Iris-setosa')
# (8, 5, 3.4, 1.5, 0.2, 'Iris-setosa')
# (9, 4.4, 2.9, 1.4, 0.2, 'Iris-setosa')
# (10, 4.9, 3.1, 1.5, 0.1, 'Iris-setosa')
# (11, 5.4, 3.7, 1.5, 0.2, 'Iris-setosa')
# (12, 4.8, 3.4, 1.6, 0.2, 'Iris-setosa')
# (13, 4.8, 3, 1.4, 0.1, 'Iris-setosa')
# (14, 4.3, 3, 1.1, 0.1, 'Iris-setosa')
# (15, 5.8, 4, 1.2, 0.2, 'Iris-setosa')
# (16, 5.7, 4.4, 1.5, 0.4, 'Iris-setosa')
# (17, 5.4, 3.9, 1.3, 0.4, 'Iris-setosa')
# (18, 5.1, 3.5, 1.4, 0.3, 'Iris-setosa')
# (19, 5.7, 3.8, 1.7, 0.3, 'Iris-setosa')
# (20, 5.1, 3.8, 1.5, 0.3, 'Iris-setosa')
# (21, 5.4, 3.4, 1.7, 0.2, 'Iris-setosa')
# (22, 5.1, 3.7, 1.5, 0.4, 'Iris-setosa')
# (23, 4.6, 3.6, 1, 0.2, 'Iris-setosa')
# (24, 5.1, 3.3, 1.7, 0.5, 'Iris-setosa')
# ...

# %%
# Column names
column_names = ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']

# Convert to DataFrame
df = pd.DataFrame(rows, columns=column_names)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
len(df)
# Out:
# 150

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
